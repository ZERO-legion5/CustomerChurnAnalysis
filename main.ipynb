# %% [markdown]
# # Data Collection

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("churn.csv")

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# # Data Analysis

# %%
data = data[data.columns[3:]]

# %%
data.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CreditScore      10000 non-null  int64
#  1   Geography        10000 non-null  str
#  2   Gender           10000 non-null  str
#  3   Age              10000 non-null  int64
#  4   Tenure           10000 non-null  int64
#  5   Balance          10000 non-null  float64
#  6   NumOfProducts    10000 non-null  int64
#  7   HasCrCard        10000 non-null  int64
#  8   IsActiveMember   10000 non-null  int64
#  9   EstimatedSalary  10000 non-null  float64
#  10  Exited           10000 non-null  int64
# dtypes: float64(2), int64(7), str(2)
# memory usage: 859.5 KB

# %%
data.shape
# Out:
# (10000, 11)

# %%
data.isnull().sum()
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
data.describe()
# Out:
#         CreditScore           Age        Tenure        Balance  NumOfProducts  \
# count  10000.000000  10000.000000  10000.000000   10000.000000   10000.000000
# mean     650.528800     38.921800      5.012800   76485.889288       1.530200
# std       96.653299     10.487806      2.892174   62397.405202       0.581654
# min      350.000000     18.000000      0.000000       0.000000       1.000000
# 25%      584.000000     32.000000      3.000000       0.000000       1.000000
# 50%      652.000000     37.000000      5.000000   97198.540000       1.000000
# 75%      718.000000     44.000000      7.000000  127644.240000       2.000000
# max      850.000000     92.000000     10.000000  250898.090000       4.000000
#
#          HasCrCard  IsActiveMember  EstimatedSalary        Exited
# count  10000.00000    10000.000000     10000.000000  10000.000000
# mean       0.70550        0.515100    100090.239881      0.203700
# std        0.45584        0.499797     57510.492818      0.402769
# ...

# %%
data.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %% [markdown]
# # Data Visualization

# %%
categorical = ["Geography", "Gender","Tenure" ,"NumOfProducts", "HasCrCard", "IsActiveMember", "Exited"]
continious = ["CreditScore", "Age", "Balance","EstimatedSalary" ]

# %%
for a in categorical:
  plt.figure()
  sns.countplot(data=data, x=a)
  plt.show()

# %%
for a in categorical:
  plt.figure()
  sns.countplot(data=data, x=a, hue="Exited", palette="Set1")
  plt.show()

# %%
for b in continious:
  plt.figure(figsize=(12,4))
  plt.subplot(1,3,1)
  sns.kdeplot(data=data, x=b, hue="Exited")
  plt.subplot(1,3,2)
  sns.histplot(data=data, x=b, hue="Exited")
  plt.subplot(1,3,3)
  sns.boxplot(data=data,x=b, hue="Exited")
  plt.show()

# %%
sns.heatmap(data.drop(columns=['Geography','Gender']).corr(), fmt=".1f", annot=True, cmap="Blues")
# Out:
# <Axes: >

# %%
data.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %% [markdown]
# # Data Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# %%
for x in ["Geography", "Gender"]:
  data[x] = LabelEncoder().fit_transform(data[x])

# %%
data.head()
# Out:
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619          0       0   42       2       0.00              1
# 1          608          2       0   41       1   83807.86              1
# 2          502          0       0   42       8  159660.80              3
# 3          699          0       0   39       1       0.00              2
# 4          850          2       0   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
x = data[data.columns[:-1]]
y = data.Exited

# %%
x
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619          0       0   42       2       0.00              1
# 1             608          2       0   41       1   83807.86              1
# 2             502          0       0   42       8  159660.80              3
# 3             699          0       0   39       1       0.00              2
# 4             850          2       0   43       2  125510.82              1
# ...           ...        ...     ...  ...     ...        ...            ...
# 9995          771          0       1   39       5       0.00              2
# 9996          516          0       1   35      10   57369.61              1
# 9997          709          0       0   36       7       0.00              1
# 9998          772          1       1   42       3   75075.31              2
# 9999          792          0       0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
scaler = MinMaxScaler()
x = scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=0)

# %% [markdown]
# # Model Training

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
model = Sequential()

model.add(Dense(units=32, activation='relu', input_dim=10))
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=32, activation='tanh'))
model.add(Dense(units=1,activation='sigmoid'))
# Out:
# c:\Users\ZEROLegion\miniconda3\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │           352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ...

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(x_train,y_train, batch_size=32, epochs=200)
# Out:
# Epoch 1/200
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8680 - loss: 0.3258
# Epoch 2/200
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8696 - loss: 0.3224
# Epoch 3/200
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8694 - loss: 0.3211
# Epoch 4/200
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8690 - loss: 0.3205
# Epoch 5/200
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8696 - loss: 0.3215
# Epoch 6/200
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8723 - loss: 0.3182
# Epoch 7/200
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8700 - loss: 0.3192
# Epoch 8/200
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8696 - loss: 0.3179
# Epoch 9/200
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8741 - loss: 0.3145
# Epoch 10/200
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8729 - loss: 0.3109
# Epoch 11/200
# ...

# %% [markdown]
# # Model Testing

# %%
ans = model.predict(x_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
y_pred = (ans > 0.5)

# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, roc_auc_score

results = {}

def metric(string, ytest, z, z_prob):
    acc = accuracy_score(ytest, z)
    f1 = f1_score(ytest, z, average="macro")
    cm = confusion_matrix(ytest, z)
    auc = roc_auc_score(ytest, z_prob)
    
    print(f"{string}")
    print(f"Accuracy: {acc:.4f}")
    print(f"F1 Score: {f1:.4f}")
    print(f"AUC ROC: {auc:.4f}")
    print("Confusion Matrix:")
    print(cm)
    
    results[string] = {
        "Accuracy": acc,
        "F1 Score": f1,
        "AUC ROC": auc,
        "Confusion Matrix": cm
    }

# %%
metric("ANN:", y_test, y_pred, ans)
# Out:
# ANN:
# Accuracy: 0.8425
# F1 Score: 0.7391
# AUC ROC: 0.8178
# Confusion Matrix:
# [[1472  123]
#  [ 192  213]]

# %% [markdown]
# # Other Machine Learning Models

# %%
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state=0)
rf_model.fit(x_train, y_train)
rf_pred = rf_model.predict(x_test)
rf_prob = rf_model.predict_proba(x_test)[:, 1]
metric("Random Forest", y_test, rf_pred, rf_prob)
# Out:
# Random Forest
# Accuracy: 0.8680
# F1 Score: 0.7667
# AUC ROC: 0.8663
# Confusion Matrix:
# [[1527   68]
#  [ 196  209]]

# %%
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=0)
xgb_model.fit(x_train, y_train)
xgb_pred = xgb_model.predict(x_test)
xgb_prob = xgb_model.predict_proba(x_test)[:, 1]
metric("XGBoost", y_test, xgb_pred, xgb_prob)
# Out:
# c:\Users\ZEROLegion\miniconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [23:04:52] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBoost
# Accuracy: 0.8485
# F1 Score: 0.7414
# AUC ROC: 0.8494
# Confusion Matrix:
# [[1492  103]
#  [ 200  205]]

# %%
lgbm_model = LGBMClassifier(random_state=0, verbosity=-1)
lgbm_model.fit(x_train, y_train)
lgbm_pred = lgbm_model.predict(x_test)
lgbm_prob = lgbm_model.predict_proba(x_test)[:, 1]
metric("LightGBM", y_test, lgbm_pred, lgbm_prob)
# Out:
# LightGBM
# Accuracy: 0.8595
# F1 Score: 0.7575
# AUC ROC: 0.8687
# Confusion Matrix:
# [[1508   87]
#  [ 194  211]]
# c:\Users\ZEROLegion\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\ZEROLegion\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(

# %%
cat_model = CatBoostClassifier(verbose=0, random_state=0)
cat_model.fit(x_train, y_train)
cat_pred = cat_model.predict(x_test)
cat_prob = cat_model.predict_proba(x_test)[:, 1]
metric("CatBoost", y_test, cat_pred, cat_prob)
# Out:
# CatBoost
# Accuracy: 0.8650
# F1 Score: 0.7630
# AUC ROC: 0.8743
# Confusion Matrix:
# [[1521   74]
#  [ 196  209]]

# %%
svc_model = SVC(probability=True, random_state=0)
svc_model.fit(x_train, y_train)
svc_pred = svc_model.predict(x_test)
svc_prob = svc_model.predict_proba(x_test)[:, 1]
metric("SVM", y_test, svc_pred, svc_prob)
# Out:
# SVM
# Accuracy: 0.8595
# F1 Score: 0.7130
# AUC ROC: 0.8243
# Confusion Matrix:
# [[1574   21]
#  [ 260  145]]

# %%
lr_model = LogisticRegression(random_state=0)
lr_model.fit(x_train, y_train)
lr_pred = lr_model.predict(x_test)
lr_prob = lr_model.predict_proba(x_test)[:, 1]
metric("Logistic Regression", y_test, lr_pred, lr_prob)
# Out:
# Logistic Regression
# Accuracy: 0.8075
# F1 Score: 0.5724
# AUC ROC: 0.7636
# Confusion Matrix:
# [[1549   46]
#  [ 339   66]]

# %% [markdown]
# # Model Comparison Summary

# %%
print("Model Comparison Leaderboard (sorted by F1 Score):\n")
sorted_results = sorted(results.items(), key=lambda x: x[1]['F1 Score'], reverse=True)

for name, m in sorted_results:
    print(f"{name}: F1={m['F1 Score']:.4f}, Accuracy={m['Accuracy']:.4f}, AUC={m['AUC ROC']:.4f}")

best_metrics = sorted_results[0][1]

print(f"\nBEST MODEL: {best_model_name}")
print(f"Best Accuracy: {best_metrics['Accuracy']:.4f}")
print(f"Best F1 Score: {best_metrics['F1 Score']:.4f}")
print(f"Best AUC ROC: {best_metrics['AUC ROC']:.4f}")
print("Best Confusion Matrix:")
print(best_metrics['Confusion Matrix'])
# Out:
# Model Comparison Leaderboard (sorted by F1 Score):
#
# Random Forest: F1=0.7667, Accuracy=0.8680, AUC=0.8663
# CatBoost: F1=0.7630, Accuracy=0.8650, AUC=0.8743
# LightGBM: F1=0.7575, Accuracy=0.8595, AUC=0.8687
# XGBoost: F1=0.7414, Accuracy=0.8485, AUC=0.8494
# ANN:: F1=0.7391, Accuracy=0.8425, AUC=0.8178
# SVM: F1=0.7130, Accuracy=0.8595, AUC=0.8243
# Logistic Regression: F1=0.5724, Accuracy=0.8075, AUC=0.7636
#
# BEST MODEL: ANN
# Best Accuracy: 0.8680
# Best F1 Score: 0.7667
# Best AUC ROC: 0.8663
# Best Confusion Matrix:
# [[1527   68]
#  [ 196  209]]
